# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://search.shopping.naver.com/best100v2/main.nhn')
soup = BeautifulSoup(res.content,'html.parser')
data = soup.select('#popular_srch_lst > li > span.txt')
for item in data:
    print(item.get_text())
# Out:
# 여성 핸드메이드 코트
# 브라운 체온계
# 여아한복
# 여성 숏패딩
# 원피스
# 나이키운동화
# 3인용쇼파
# 삼성노트북
# 스커트
# 리스테린

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000')
soup = BeautifulSoup(res.content,'html.parser')
data = soup.select('#productListArea > ul > li > p')
for item in data:
    print(item.get_text())
# Out:
# 순면 기모 체크 커플 파자마 잠옷 홈웨어
#
#
# GGPX 카라 폭스퍼 숏 구스패딩 GJDBDU992F
#
#
# 내셔널지오그래픽 오터 플리스 뽀글이 풀 집...
#
#
# 나이키 NSW 테크플리스 조거 팬츠 805163-0...
#
#
# 지오다노 퀄팅 경량 조끼 379902
#
#
# 지오다노 목넥 푸파 다운 079920
#
#
# 내셔널지오그래픽 카이만 3 구스 다운 롱패...
#
#
# 라코스테 남성 숏 구스 다운 BH681E-19DYZP
#
#
# 지오다노 크루넥 경량 패딩조끼 379903
#
#
# 오조이 자체제작 울 30 플리츠 모직 롱 밴딩...
#
#
# 타미힐피거 남녀공용 기모자수맨투맨
#
#
# 에고이스트 와이드 폭스퍼 구스 롱다운 EK4...
#
#
# 리스트 핸드메이드 벨티드 울 캐시미어 코트...
#
#
# 폴햄 남여공용 알래스카 롱패딩 다운 점퍼 ...
#
#
# 컨셉원 써모라이트 슬림핏 기모 슬랙스 101...
#
#
# 에고이스트 라글란 볼륨 구스 숏다운 EK4TD...
#
#
# 쉬즈미스 헨드메이드 벨트라인 코트 SWHCTJ...
#
#
# 클라이드앤 경량 다운 롱패딩 CJDDU903F
#
#
# 지오다노 초경량 퀼팅 숏자켓 379907
#
#
# 지컷 큐트 폭스퍼 후드 구스다운 점퍼 7259...
#
#
# 시슬리 폭스 퍼 구스다운 패딩 SAPD80961
#
#
# 아디다스 락업 트랙팬츠 우먼스 LOCK UP TP...
#
#
# 온앤온 19겨울 폭스후드 구스 숏패딩 NP9WM...
#
#
# 뉴발란스 공용 2019년 UNI 액티브 구스 숏 ...
#
#
# 지오다노 여 메리노울 크루넥 스웨터 7GG 3...
#
#
# 지컷 롱벨티드 패딩 7259417004
#
#
# 일리코 코듀로이 밍크안감 배기 밴딩팬츠 골...
#
#
# 지오다노 여 초경량 퀼팅 숏자켓379907  37...
#
#
# 내셔널지오그래픽 헤론 라이트 덕 U넥 이너...
#
#
# 앤드지 andz BY 실버폭스퍼 럭스마스터 구스...
#
#
# 빈폴 폭스퍼 소피 다운 점퍼 BF9X38U015
#
#
# 지오다노 여 캐주얼 롱 다운 378920
#
#
# 지오다노 울 코트 079914
#
#
# 트리플에이 AAA 무지티 반팔티셔츠 1301 16...
#
#
# 하이드아웃 셀럽 Season3 지킬앤하이드 리버...
#
#
# 남자 9부 겨울 기모 면 스판 치노 슬랙스 밴...
#
#
# 남자 가을 겨울 스판 편한 밴딩 슬랙스 면바...
#
#
# GGPX 벨티드 핸드메이드코트 GJDBCT992F
#
#
# 지오다노 여 크루넥 경량 다운 자켓 379905
#
#
# 빈폴 레이디스 애쉬 A라인 폭스퍼 소피 다운...
#
#
# 나이키 우먼스 테크 플리스 팬츠 BV3473-01...
#
#
# 남녀공용 착한 커플 숏패딩
#
#
# 폴로랄프로렌 여성 크루넥 코튼 케이블 니트
#
#
# 파타고니아 남녀공용 후드티
#
#
# 플라스틱아일랜드 핏앤에이 벨트 다운 점퍼...
#
#
# 지오다노 브러쉬드 테리 조거 팬츠 419924
#
#
# 파타고니아 레트로 x 후리스 플리스 자켓
#
#
# 쉬즈미스 울 캐시미어 슬릿 벨티드 코트 SW...
#
#
# 폴로랄프로렌 하프집업 니트 맨투맨
#
#
# 푸마 기능성 드로즈 프레쉬스킨 12종 패키지
#
#
# 여성면팬티 순면 모달팬티 노라인 햄라인
#
#
# 게스 여성 기모 슬림 부츠컷 청바지 OJ4D03...
#
#
# 폴햄 프리미엄 덕 롱패딩 PHY4JP3110
#
#
# 탑걸 심플 폭스 퍼 덕다운점퍼 TJDADU904F
#
#
# 온앤온 폭스 퍼 후드 구스 숏 패딩 NP9WM60...
#
#
# 다니엘에스떼 래빗 풀스킨 폭스퍼 구스코트
#
#
# 지오지아 솔리드 푸퍼 구스다운 숏다운 AEZ...
#
#
# 지컷 야상다운 폭스 점퍼 7259417006
#
#
# 마인드브릿지 울 캐시 스탠다드 싱글코트 M...
#
#
# 아디다스 GS 남성 쿨썸머 블랙패키지 드로즈...
#
#
# 타미힐피거 남녀공용 양면기모 맨투맨 BJ
#
#
# 아디다스 우먼 파이어버드 트랙팬츠 ED7509
#
#
# 써스데이아일랜드 루즈핏 코쿤 폭스퍼 숏 다...
#
#
# 게스 19FW 남녀공용 심리스 다운 롱패딩 MJ...
#
#
# 에고이스트 체크 더블 루즈핏 핸드메이드 코...
#
#
# 빅사이즈 남자팬티 드로즈속옷 7종
#
#
# SOUP 후디 핸드메이드 코트 SVAHCF0
#
#
# 리스트 파이핑 포켓 울 캐시미어 코트 TWHC...
#
#
# 완전편한 도톰 융기모 9부 밴딩슬랙스 4컬러
#
#
# 폴햄 남성 캐시미어 목폴라 PHZ4EU1010
#
#
# 아디다스 파이어버드 트랙팬츠 FIREBIRD TP...
#
#
# 더핸드메이드 울 블렌디드 핸드메이드 벨티...
#
#
# 리스트 싱글 버튼 핸드메이드 울 코트 TWHC...
#
#
# 쉬즈미스 폭스포인트 롱구스다운 SSDJPJ420...
#
#
# 올젠 OLZEN 뉴테라 액티브 라이트 롱다운 Z...
#
#
# 폴로랄프로렌 남성 케이블 니트 10컬러
#
#
# 릴리전 부퍼 숏패딩 점퍼
#
#
# 크리스티나앤코 니트 라운지웨어 세트
#
#
# 나이키 테크 플리스 조거팬츠 805162-010
#
#
# 플라스틱아일랜드 벨벳 플리츠 스커트 PK4W...
#
#
# 지오다노 반팔 티셔츠 243801
#
#
# 나이스크랍 루즈핏 더블 코트 N194XWCA47
#
#
# 지컷 럭셔리 퍼트리밍 패딩 7259417007
#
#
# 고트혼 울 90 더블 버튼 클래식 핸드메이드...
#
#
# 내셔널지오그래픽 폴리카터 스몰로고 맨투맨...
#
#
# 올젠 뉴테라 사파리다운 ZOZ4FP1309
#
#
# 오플 19FW 양면스트레치 기모본딩 팬츠4종
#
#
# 나이키 트레이닝복 백 플리스 기모 조거팬츠
#
#
# 캉골 후다드 숏 다운 9548
#
#
# 탑걸 핸드메이드 오버핏 코트 TJDACT927F
#
#
# 마르조 여성 본딩 밴딩 팬츠 4종
#
#
# 나이키 브라 우먼스 쉐이즈 ZIP 스포츠브라...
#
#
# 쉬즈미스 19FW 울 캐시미어 벨티드 코트 SW...
#
#
# 히든 버튼 핸드메이드 코트
#
#
# 올젠 캐시미어 라운드 스웨터 ZOZ4ER1304
#
#
# 나이스크랍 폭스퍼 롱 패딩점퍼 N194YWDA01
#
#
# 보웬 홀가 루즈 골지 원피스
#
#
# 지오다노 여 브러시드 부츠컷 팬츠 솔리드 ...
#
#
# 리스트 울 캐시미어 벨티드 코트 TWWCTJ800...
#
#
# 앤드지 andz BY 2019 폭스퍼 구스 맥스다운...

# %%
import requests
from bs4 import BeautifulSoup

site_list=['https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000','https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001']

for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content,'html.parser')
    data = soup.select('#productListArea > ul > li > p')
    print(site)
    for item in data:
        print(item.get_text())
# Out:
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000
#
# 순면 기모 체크 커플 파자마 잠옷 홈웨어
#
#
# GGPX 카라 폭스퍼 숏 구스패딩 GJDBDU992F
#
#
# 내셔널지오그래픽 오터 플리스 뽀글이 풀 집...
#
#
# 나이키 NSW 테크플리스 조거 팬츠 805163-0...
#
#
# 지오다노 퀄팅 경량 조끼 379902
#
#
# 지오다노 목넥 푸파 다운 079920
#
#
# 내셔널지오그래픽 카이만 3 구스 다운 롱패...
#
#
# 라코스테 남성 숏 구스 다운 BH681E-19DYZP
#
#
# 지오다노 크루넥 경량 패딩조끼 379903
#
#
# 오조이 자체제작 울 30 플리츠 모직 롱 밴딩...
#
#
# 타미힐피거 남녀공용 기모자수맨투맨
#
#
# 에고이스트 와이드 폭스퍼 구스 롱다운 EK4...
#
#
# 리스트 핸드메이드 벨티드 울 캐시미어 코트...
#
#
# 폴햄 남여공용 알래스카 롱패딩 다운 점퍼 ...
#
#
# 컨셉원 써모라이트 슬림핏 기모 슬랙스 101...
#
#
# 에고이스트 라글란 볼륨 구스 숏다운 EK4TD...
#
#
# 쉬즈미스 헨드메이드 벨트라인 코트 SWHCTJ...
#
#
# 클라이드앤 경량 다운 롱패딩 CJDDU903F
#
#
# 지오다노 초경량 퀼팅 숏자켓 379907
#
#
# 지컷 큐트 폭스퍼 후드 구스다운 점퍼 7259...
#
#
# 시슬리 폭스 퍼 구스다운 패딩 SAPD80961
#
#
# 아디다스 락업 트랙팬츠 우먼스 LOCK UP TP...
#
#
# 온앤온 19겨울 폭스후드 구스 숏패딩 NP9WM...
#
#
# 뉴발란스 공용 2019년 UNI 액티브 구스 숏 ...
#
#
# 지오다노 여 메리노울 크루넥 스웨터 7GG 3...
#
#
# 지컷 롱벨티드 패딩 7259417004
#
#
# 일리코 코듀로이 밍크안감 배기 밴딩팬츠 골...
#
#
# 지오다노 여 초경량 퀼팅 숏자켓379907  37...
#
#
# 내셔널지오그래픽 헤론 라이트 덕 U넥 이너...
#
#
# 앤드지 andz BY 실버폭스퍼 럭스마스터 구스...
#
#
# 빈폴 폭스퍼 소피 다운 점퍼 BF9X38U015
#
#
# 지오다노 여 캐주얼 롱 다운 378920
#
#
# 지오다노 울 코트 079914
#
#
# 트리플에이 AAA 무지티 반팔티셔츠 1301 16...
#
#
# 하이드아웃 셀럽 Season3 지킬앤하이드 리버...
#
#
# 남자 9부 겨울 기모 면 스판 치노 슬랙스 밴...
#
#
# 남자 가을 겨울 스판 편한 밴딩 슬랙스 면바...
#
#
# GGPX 벨티드 핸드메이드코트 GJDBCT992F
#
#
# 지오다노 여 크루넥 경량 다운 자켓 379905
#
#
# 빈폴 레이디스 애쉬 A라인 폭스퍼 소피 다운...
#
#
# 나이키 우먼스 테크 플리스 팬츠 BV3473-01...
#
#
# 남녀공용 착한 커플 숏패딩
#
#
# 폴로랄프로렌 여성 크루넥 코튼 케이블 니트
#
#
# 파타고니아 남녀공용 후드티
#
#
# 플라스틱아일랜드 핏앤에이 벨트 다운 점퍼...
#
#
# 지오다노 브러쉬드 테리 조거 팬츠 419924
#
#
# 파타고니아 레트로 x 후리스 플리스 자켓
#
#
# 쉬즈미스 울 캐시미어 슬릿 벨티드 코트 SW...
#
#
# 폴로랄프로렌 하프집업 니트 맨투맨
#
#
# 푸마 기능성 드로즈 프레쉬스킨 12종 패키지
#
#
# 여성면팬티 순면 모달팬티 노라인 햄라인
#
#
# 게스 여성 기모 슬림 부츠컷 청바지 OJ4D03...
#
#
# 폴햄 프리미엄 덕 롱패딩 PHY4JP3110
#
#
# 탑걸 심플 폭스 퍼 덕다운점퍼 TJDADU904F
#
#
# 온앤온 폭스 퍼 후드 구스 숏 패딩 NP9WM60...
#
#
# 다니엘에스떼 래빗 풀스킨 폭스퍼 구스코트
#
#
# 지오지아 솔리드 푸퍼 구스다운 숏다운 AEZ...
#
#
# 지컷 야상다운 폭스 점퍼 7259417006
#
#
# 마인드브릿지 울 캐시 스탠다드 싱글코트 M...
#
#
# 아디다스 GS 남성 쿨썸머 블랙패키지 드로즈...
#
#
# 타미힐피거 남녀공용 양면기모 맨투맨 BJ
#
#
# 아디다스 우먼 파이어버드 트랙팬츠 ED7509
#
#
# 써스데이아일랜드 루즈핏 코쿤 폭스퍼 숏 다...
#
#
# 게스 19FW 남녀공용 심리스 다운 롱패딩 MJ...
#
#
# 에고이스트 체크 더블 루즈핏 핸드메이드 코...
#
#
# 빅사이즈 남자팬티 드로즈속옷 7종
#
#
# SOUP 후디 핸드메이드 코트 SVAHCF0
#
#
# 리스트 파이핑 포켓 울 캐시미어 코트 TWHC...
#
#
# 완전편한 도톰 융기모 9부 밴딩슬랙스 4컬러
#
#
# 폴햄 남성 캐시미어 목폴라 PHZ4EU1010
#
#
# 아디다스 파이어버드 트랙팬츠 FIREBIRD TP...
#
#
# 더핸드메이드 울 블렌디드 핸드메이드 벨티...
#
#
# 리스트 싱글 버튼 핸드메이드 울 코트 TWHC...
#
#
# 쉬즈미스 폭스포인트 롱구스다운 SSDJPJ420...
#
#
# 올젠 OLZEN 뉴테라 액티브 라이트 롱다운 Z...
#
#
# 폴로랄프로렌 남성 케이블 니트 10컬러
#
#
# 릴리전 부퍼 숏패딩 점퍼
#
#
# 크리스티나앤코 니트 라운지웨어 세트
#
#
# 나이키 테크 플리스 조거팬츠 805162-010
#
#
# 플라스틱아일랜드 벨벳 플리츠 스커트 PK4W...
#
#
# 지오다노 반팔 티셔츠 243801
#
#
# 나이스크랍 루즈핏 더블 코트 N194XWCA47
#
#
# 지컷 럭셔리 퍼트리밍 패딩 7259417007
#
#
# 고트혼 울 90 더블 버튼 클래식 핸드메이드...
#
#
# 내셔널지오그래픽 폴리카터 스몰로고 맨투맨...
#
#
# 올젠 뉴테라 사파리다운 ZOZ4FP1309
#
#
# 오플 19FW 양면스트레치 기모본딩 팬츠4종
#
#
# 나이키 트레이닝복 백 플리스 기모 조거팬츠
#
#
# 캉골 후다드 숏 다운 9548
#
#
# 탑걸 핸드메이드 오버핏 코트 TJDACT927F
#
#
# 마르조 여성 본딩 밴딩 팬츠 4종
#
#
# 나이키 브라 우먼스 쉐이즈 ZIP 스포츠브라...
#
#
# 쉬즈미스 19FW 울 캐시미어 벨티드 코트 SW...
#
#
# 히든 버튼 핸드메이드 코트
#
#
# 올젠 캐시미어 라운드 스웨터 ZOZ4ER1304
#
#
# 나이스크랍 폭스퍼 롱 패딩점퍼 N194YWDA01
#
#
# 보웬 홀가 루즈 골지 원피스
#
#
# 지오다노 여 브러시드 부츠컷 팬츠 솔리드 ...
#
#
# 리스트 울 캐시미어 벨티드 코트 TWWCTJ800...
#
#
# 앤드지 andz BY 2019 폭스퍼 구스 맥스다운...
#
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001
#
# 나이키 모자 헤리티지 86 퓨추라 캡 913011...
#
#
# 컨버스 척테일러1970s 하이 클래식 162050C
#
#
# 나이키 모자 스우시캡 레가시91 볼캡 89265...
#
#
# 컨버스 X JW 앤더슨 런스타 하이크 164840C
#
#
# 나이키 에어 맥스 2017 트리플
#
#
# 디스커버리익스페디션 공용 미토 DXSH13911
#
#
# 반스 클래식 어센틱 스니커즈 블랙 VN000EE...
#
#
# 내셔널지오그래픽 캐리어 세트 스페이스 캐...
#
#
# 아메리칸투어리스터 FLINT 캐리어 2종 세트...
#
#
# 라이프썸 듀얼 디지털 스톱워치 LFS-HA12
#
#
# 나이키 에어맥스97 트리플화이트 921522-10...
#
#
# 나이키 레볼루션 5 BQ3204-002
#
#
# 아디다스 팔콘  B28128
#
#
# 베이직삭스 학생양말 10켤레 국산 교복 무지...
#
#
# 골든구스 슈퍼스타 GCOWS590 W77 화이트
#
#
# 몽블랑 남성 사토리얼 반지갑 113215
#
#
# 드레텍 일본 스탑워치
#
#
# 블랙마켓 남자 여자국산 3단 실리콘페이크삭...
#
#
# 구찌 G버클 가죽벨트 여자용 409417
#
#
# 아디다스 WOMEN MEN RUNNING 런 팔콘 EG F3...
#
#
# 닥스 남녀 모직장갑 7종 DG7
#
#
# 지오다노 01134600 리버서블 래더 벨트 134...
#
#
# 구찌 마이크로시마 여성 반지갑 449395
#
#
# 나이키 에어 테일윈드 79 487754-100
#
#
# 반스 올드스쿨 스니커즈 VN000D3HY28 블랙
#
#
# 나이키 에어맥스 97 트리플 올블랙 BQ4567-...
#
#
# 가드링 레이어드 실반지
#
#
# 컨버스 척테일러 올스타 1970S OX 모음 162...
#
#
# 아디다스 팔콘 블랙 B28129
#
#
# 내셔널지오그래픽 백팩 빅로고 버디 백팩 N...
#
#
# 루이까또즈 미니지갑 SL1AL03BL
#
#
# 나이키 런닝화 에어맥스 엑시스 AA2146-100
#
#
# 나이키 에어 맥스 95 트리플블랙 남성용 AT...
#
#
# 내셔널지오그래픽 백팩 빅로고 프라임 백팩...
#
#
# 반스 올드스쿨 라이트 레더 VN0A2Z5WNQS
#
#
# 닥스 남성 가죽장갑 GPA310X
#
#
# 아메리칸투어리스터 AIR RIDER 여행가방 5종...
#
#
# 몽블랑 남성용 양면벨트 38157 은장 514001...
#
#
# 마크제이콥스 로고스트랩 스냅샷 스몰 카메...
#
#
# 일본 드레텍 스탑워치
#
#
# 아디다스 울트라부스트 20 M EG0691
#
#
# MLB 빅볼청키 LA다저스 뉴욕양키스 보스턴
#
#
# 홈버프 발편한 EVA 푹신한 실내화 학교 학생...
#
#
# 아디다스 슈퍼스타 C77124
#
#
# 닥터마틴 닥터 패트리샤 다크브라운 247542...
#
#
# 나이키 에어맥스 720 AO2924-007
#
#
# 구찌 국내당일 19FW 마이크로시마 남성 반지...
#
#
# 나이키 에어맥스 엑시스 W AIR MAX AXIS AA...
#
#
# 베어파우 와플 부티 Waffle Buti 부츠
#
#
# 나이키 운동화 에어 맥스 97 트리플블랙 AI...
#
#
# 휠라 디스럽터 2 테이피테잎  FS1HTB1091X
#
#
# 나이키 에어 모나크 IV 블랙 + 화이트 4154...
#
#
# 컨버스 척 70 클래식(신)  162058C
#
#
# 컨버스 척테일러 올스타 클래식 블랙 M9166...
#
#
# 내셔널지오그래픽 캐리어세트 NG 여행용 캐...
#
#
# 휠라 디스럽터 2 FS1HTB1071X
#
#
# 토리버치 맥그로우 카메라백 50584
#
#
# 나이키 베이퍼맥스 플라이니트3 나코탭 트리...
#
#
# 언니네양말 여성 긴목 가을겨울 무지양말
#
#
# 1290 무지 기본 골지 양말
#
#
# 베어풋사이언스 아치시스템인솔 기능성깔창...
#
#
# 라이프굿즈 밸런스풋패드 바른자세 깔창
#
#
# 기성일 발바닥 쿠션 깔창
#
#
# 나이키 우먼스 에어맥스 270 화이트 AH6789...
#
#
# 홈버프 푹신한 EVA 털 실내화 사무실 학생 ...
#
#
# 나이키 에어 테일윈드 79 487754-012
#
#
# 프라다 테수토 체인 스트랩 숄더백 1BH204
#
#
# 컨버스 X JW 앤더슨 런스타 하이크 164665C
#
#
# 나이키 오프화이트 X 와플레이서 CD8180-10...
#
#
# 구찌 시마 웹 투톤 머플러 325806   3컬러
#
#
# 나이키 우먼스 에어맥스 95 CI3710-600
#
#
# 호주정품 어그슬리퍼 천송이슬리퍼 오즈웨어
#
#
# 닥터마틴 1461 모노 3홀 스무스 R14345001
#
#
# 컨버스 척 테일러 올스타 리프트 캔버스 56...
#
#
# 아디다스 울트라부스트 EH1420
#
#
# 스와로브스키 NICE 로듐 이어링 5482912
#
#
# 발렌시아가 애트니 파피에르 A6 미니백 DLQ...
#
#
# 스와로브스키 NAUGHTY MINI 로즈골드 네크리...
#
#
# 뉴발란스 19FW 남여공용 NB 2PIK 백팩 5컬러...
#
#
# 로라로라 MF-19739 RUFFLE KNIT MUFFLER BL...
#
#
# 몽블랑 4810 웨스트사이드 남성 반지갑 114...
#
#
# 타미힐피거 플래그 베이스볼 캡 TMMT1AHE01...
#
#
# 뉴발란스 운동화 남여공용 운동화 헤리티지...
#
#
# SBD벨트 L사이즈
#
#
# 고비 캐시미어 베이직 머플러 정식 수입원
#
#
# 구찌 마몬트 마틀라쎄 스몰 DTD1T 1000 447...
#
#
# 카시오 손석희 앵커 시계 외 A168WA A-168W...
#
#
# 휠라 운동화 베이직라인 탑셀러 10종 모음
#
#
# 컨버스 척테일러 올스타 클래식 블랙 AM916...
#
#
# 닥스 ACC 캐시미어머플러 FIF7A279-BS
#
#
# 나이키 에어맥스 97 팬텀베이지 921733007
#
#
# 나이키 조이라이드 듀얼 런 CD4365-001
#
#
# 구찌 마몬트 카드지갑 컬러 456126
#
#
# 나이키 에어맥스 97 트리플화이트 921826-1...
#
#
# 컨버스 캔버스화 144757c 블랙+화이트
#
#
# 내셔널지오그래픽 백팩 빅로고 스탠다드백팩...
#
#
# 루이까또즈 캐시미어 머플러 데일리 캐시미...
#
#
# 내셔널지오그래픽 캐리어 NG 화물용 캐리어...
#
#
# 라코스테 남성 CARNABY 스니커즈 LCST RZ00...
#
#
# 뉴에라 뉴욕/LA 베이직 볼캡 12098015 1209...
