# %%
import requests
import pprint

client_id = client_id = "hello!"
client_secret = "hello!"

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=android'
header_params = {"X-Naver-Client-ID":client_id, "X-Naver-Client-Secret":client_secret}
res = requests.get(naver_open_api, headers=header_params)

if res.status_code == 200:
    #data = res.json()
    #print(data)
    #print (res.text)
    #print(data['items'][0]['title'])
    #pprint.pprint(data)
    
    for index, item in enumerate(data['items']):
        print(index + 1, item['title'],item['link'])
    
else:
    print("Error Code", res.status.code)
# Out:
# 1 범용 <b>안드로이드</b> 올인원 매립 네비게이션 PX6 익스트림 에디션 유니버셜 7인치 / 10인치 https://search.shopping.naver.com/gate.nhn?id=82113730741
# 2 파인디지털 파인드라이브 Q30 https://search.shopping.naver.com/gate.nhn?id=18711239261
# 3 파인디지털 파인드라이브 Q300 https://search.shopping.naver.com/gate.nhn?id=19490416717
# 4 파인디지털 파인드라이브 Q100 Black https://search.shopping.naver.com/gate.nhn?id=13854813056
# 5 파인디지털 파인드라이브 T https://search.shopping.naver.com/gate.nhn?id=19551877065
# 6 파인디지털 파인드라이브 A1 https://search.shopping.naver.com/gate.nhn?id=13422382381
# 7 팅크웨어 아이나비 LS500T https://search.shopping.naver.com/gate.nhn?id=17163520084
# 8 Junsun E31 pro <b>안드로이드</b> 차량용 네비게이션 준선 네비 대시보드 티맵 https://search.shopping.naver.com/gate.nhn?id=82012253757
# 9 팅크웨어 아이나비 M500 https://search.shopping.naver.com/gate.nhn?id=15140462505
# 10 팅크웨어 아이나비 LS500 https://search.shopping.naver.com/gate.nhn?id=14869780871

# %%
import os
import sys
import urllib.request

client_id = "Hello Wolrd"
client_secret = "Hello World"
encText = urllib.parse.quote("삼성전자")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Fri, 10 Jan 2020 11:27:31 +0900",
# "total": 2712734,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>삼성전자</b> 주식투자 수익을 위한 핵심요약 정리!",
# "link": "https:\/\/blog.naver.com\/hyva76?Redirect=Log&logNo=221754822474",
# "description": "오늘은 외국인투자자들이 매도를 했지만12월 중순이후 외국인투자자들은 전기전자업종을 집중매수하며, 특히 <b>삼성전자</b>와 sk하이닉스 주식에계속해서 러브콜을 보냈었죠. 오늘 증시에서는 외국인이... ",
# "bloggername": "정전무 주식채널",
# "bloggerlink": "https://blog.naver.com/hyva76",
# "postdate": "20191231"
#
# },
# {
# "title": "<b>삼성전자</b> 주식? 대박나는 투자법이 있을까?",
# "link": "https:\/\/blog.naver.com\/pyunjo?Redirect=Log&logNo=221761513409",
# "description": "<b>삼성전자</b> 주봉 차트 치킨전문점에 가서 메뉴를 보고 주문을 하려고 한다. 1. 가장 베스트 메뉴고 자주... <b>삼성전자</b>, 하이닉스 등 기관도 마찬가지. 2. 치킨이 아닌 감자튀김을 주문한다. - 왜 베스트 음식 놔두고... ",
# "bloggername": "증권 전문투자자 '절대패턴'",
# "bloggerlink": "https://blog.naver.com/pyunjo",
# "postdate": "20200106"
#
# },
# {
# "title": "평택 고덕 센트리마 <b>삼성전자</b> 앞 오피스텔 상가",
# "link": "https:\/\/blog.naver.com\/emily_jang?Redirect=Log&logNo=221729125949",
# "description": "합니다 <b>삼성전자</b> 메인 출입구에 직결해 있으며 3면이 대로변 코너자리, 횡단보도가 직결 되어 잇는 절대목으로 삼성 바로 앞을 독점한 최고의 입지 조건을 자랑하는 곳입니다 평택반도체 라인은 세계 최대인... ",
# "bloggername": "名品하우스",
# "bloggerlink": "https://blog.naver.com/emily_jang",
# "postdate": "20191206"
#
# },
# {
# "title": "<b>삼성전자</b> 주가전망 더 매수해야 할까?",
# "link": "https:\/\/blog.naver.com\/dlwltjd0619?Redirect=Log&logNo=221741784033",
# "description": "이번 산성전자의 투자 역시 메모리 반도체 시장의 더욱 긍정적인 영향을 줄것으로 예상되며 역시 <b>삼성전자</b>의 호재영향이라고 볼 수 있습니다. 위에서 말씀드린 5G 스마트폰 증가와 함께 더 매수해야 하는... ",
# "bloggername": "정보마당",
# "bloggerlink": "https://blog.naver.com/dlwltjd0619",
# "postdate": "20191218"
#
# },
# {
# "title": "<b>삼성전자</b>로 보는 내년 증시 전망  (하울신당의 역발상)",
# "link": "https:\/\/blog.naver.com\/nlueoxy?Redirect=Log&logNo=221750018555",
# "description": "<b>삼성전자</b>가 올해 4만원 밑으로 빠질 것이라는 전망이 있었다. 많은 이들이 한국경제를 암울하게 보고 있다. 이재용 부회장의 형량이 크게 늘어날 가능성이 높아지자 <b>삼성전자</b>에 대한 기대가 사그러 들었다.... ",
# "bloggername": "용하다 인베스트",
# "bloggerlink": "https://blog.naver.com/nlueoxy",
# "postdate": "20191226"
#
# },
# {
# "title": "[IBK투자증권의 기업분석] <b>삼성전자</b> - 4분기 기대 이상",
# "link": "https:\/\/blog.naver.com\/ibks_pr?Redirect=Log&logNo=221765074267",
# "description": "IBK투자증권의 기업분석 <b>삼성전자</b>를 알아보겠습니다 <b>삼성전자</b> (005930) 4분기 기대 이상 • 4분기 잠정 실적 매출액은 59조, 영업이익은 7.1조 <b>삼성전자</b> 2019년 4분기 잠정 실적 매출액은 59조원, 영업이익은 7.... ",
# "bloggername": "IBK투자증권, 그들의 즐거운 이야기",
# "bloggerlink": "https://blog.naver.com/ibks_pr",
# "postdate": "20200109"
#
# },
# {
# "title": "<b>삼성전자</b> 미니빔프로젝터 SSB-12DLWA10 카카오 라이언",
# "link": "https:\/\/blog.naver.com\/foolhun3?Redirect=Log&logNo=221729928814",
# "description": "중 '<b>삼성전자</b> 미니빔프로젝터 SSB-12DLWA1 카카오 라이언'을 사용할 기회를 얻었는데요. 이건 뭐~ 빔 그... 삼성 미니빔 빔프로젝터 스마트빔 스마트폰 무선미러링 호환 : 삼성공식파트너 마루느루 빔프로젝터... ",
# "bloggername": "후니와 놀자",
# "bloggerlink": "https://blog.naver.com/foolhun3",
# "postdate": "20191207"
#
# },
# {
# "title": "<b>삼성전자</b> 갤럭시북 이온 실제 구매 후기(#내돈후기)",
# "link": "https:\/\/blog.naver.com\/sykun9474?Redirect=Log&logNo=221750557333",
# "description": "이번에 출시한 <b>삼성전자</b> 갤럭시 북 시리즈들은 <b>삼성전자</b>에서 칼을 갈고 나온듯 합니다. 네이밍도 기존에 삼성노트북 9, Pen S등에서 갤럭시로 전환한 것을 보면 상당히 공을 들였고 경쟁사와 다르게 많은... ",
# "bloggername": "크리에이터 달꿀이의 블로그",
# "bloggerlink": "https://blog.naver.com/sykun9474",
# "postdate": "20191227"
#
# },
# {
# "title": "GSAT공부방법, 교재로 <b>삼성전자</b>공채에 맞춰서!",
# "link": "https:\/\/blog.naver.com\/randy38?Redirect=Log&logNo=221763021672",
# "description": "이러한 삼성의 이념을 바탕으로 하여 본격적으로 <b>삼성전자</b>공채를 준비해 나가는데 집중을 했습니다. 삼성의 채용시기는 상반기와 하반기에 나뉘어져 채용이 진행된다는 것을 알 수 있었는데요, 상반기인... ",
# "bloggername": "꽃돌의 아트기타",
# "bloggerlink": "https://blog.naver.com/randy38",
# "postdate": "20200107"
#
# },
# {
# "title": "연구개발투자(R&amp;D), 세계2위 <b>삼성전자</b>",
# "link": "https:\/\/blog.naver.com\/kdw9763?Redirect=Log&logNo=221746351258",
# "description": "대한민국 대표기업 <b>삼성전자</b>가 2018년 기준 세계에서 연구개발(R&amp;D)에 두 번째로... 에서 <b>삼성전자</b>는 2018회계연도 R&amp;D 투자액 2위를 기록했다. 1위 기업은 구글의 모회사인... ",
# "bloggername": "고객만족마케팅전략 세계최고가치순위 마케팅트렌드",
# "bloggerlink": "https://blog.naver.com/kdw9763",
# "postdate": "20191223"
#
# }
# ]
# }
