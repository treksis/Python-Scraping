# %%
Image(filename='Cap 2020-01-07 16-26-52-432.jpg')

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.amazon.ca/charts/2019-12-29/mostread/fiction?ref=chrt_bk_dx_intra_rd_fc')
soup = BeautifulSoup(res.content,'html.parser')
data = soup.select('div.kc-rank-card-title')
for item in data:
    print(item.get_text())
# Out:
#                         Harry Potter and the Philosopher's Stone
#
#
#                         Indian Horse
#
#
#                         The Testaments
#
#
#                       Harry Potter and the Order of the Phoenix
#
#
#                       Harry Potter and the Goblet of Fire
#
#
#                       Blood of Elves
#
#
#                       Where the Crawdads Sing
#
#
#                       The Guardians
#
#
#                       Harry Potter and the Deathly Hallows
#
#
#                       Harry Potter and the Half-Blood Prince
#
#
#                       Harry Potter and the Prisoner of Azkaban
#
#
#                       The Institute
#
#
#                       The Handmaid's Tale
#
#
#                       Harry Potter and the Chamber of Secrets
#
#
#                       The Night Fire
#
#
#                       Sherlock Holmes
#
#
#                       The Last Wish
#
#
#                       The Silent Patient
#
#
# ...

# %%
Image(filename='Cap 2020-01-07 16-36-28-172.png')

# %%
amazon_bestseller = ['https://www.amazon.ca/charts/2019-12-29/mostread/fiction?ref=chrt_bk_dx_intra_rd_fc', 
                     'https://www.amazon.ca/charts/2019-12-29/mostread/nonfiction?ref=chrt_bk_dx_intra_nf_rd'
                    ]

for amazon_site in amazon_bestseller:
    res = requests.get(amazon_site)
    soup = BeautifulSoup(res.content,'html.parser')
    data = soup.select('div.kc-rank-card-title')
    print(amazon_site)
    for item in data:
        print(item.get_text())
# Out:
# https://www.amazon.ca/charts/2019-12-29/mostread/fiction?ref=chrt_bk_dx_intra_rd_fc
#
#                         Harry Potter and the Philosopher's Stone
#
#
#                         Indian Horse
#
#
#                         The Testaments
#
#
#                       Harry Potter and the Order of the Phoenix
#
#
#                       Harry Potter and the Goblet of Fire
#
#
#                       Blood of Elves
#
#
#                       Where the Crawdads Sing
#
#
#                       The Guardians
#
#
#                       Harry Potter and the Deathly Hallows
#
#
#                       Harry Potter and the Half-Blood Prince
#
#
#                       Harry Potter and the Prisoner of Azkaban
#
#
#                       The Institute
#
#
#                       The Handmaid's Tale
#
#
#                       Harry Potter and the Chamber of Secrets
#
#
#                       The Night Fire
#
#
#                       Sherlock Holmes
#
#
# ...

# %%
from IPython.display import Image
Image(filename='Cap 2020-01-07 15-46-58-761.jpg')

# %%
import requests
from bs4 import BeautifulSoup


site_list=['https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000',
'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001',
'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000002',
'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000004',
'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000005'
]


for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content,'html.parser')
    data = soup.select('#productListArea > ul > li > p')
    print(site)
    for item in data:
        print(item.get_text())
# Out:
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000
#
# 순면 기모 체크 커플 파자마 잠옷 홈웨어
#
#
# GGPX 카라 폭스퍼 숏 구스패딩 GJDBDU992F
#
#
# 내셔널지오그래픽 오터 플리스 뽀글이 풀 집...
#
#
# 나이키 NSW 테크플리스 조거 팬츠 805163-0...
#
#
# 지오다노 목넥 푸파 다운 079920
#
#
# 지오다노 퀄팅 경량 조끼 379902
#
#
# 내셔널지오그래픽 카이만 3 구스 다운 롱패...
#
#
# 라코스테 남성 숏 구스 다운 BH681E-19DYZP
#
#
# 지오다노 크루넥 경량 패딩조끼 379903
#
#
# 오조이 자체제작 울 30 플리츠 모직 롱 밴딩...
#
#
# 타미힐피거 남녀공용 기모자수맨투맨
#
#
# 에고이스트 와이드 폭스퍼 구스 롱다운 EK4...
#
#
# 리스트 핸드메이드 벨티드 울 캐시미어 코트...
#
#
# 폴햄 남여공용 알래스카 롱패딩 다운 점퍼 ...
#
#
# 컨셉원 써모라이트 슬림핏 기모 슬랙스 101...
#
#
# 에고이스트 라글란 볼륨 구스 숏다운 EK4TD...
#
#
# 쉬즈미스 헨드메이드 벨트라인 코트 SWHCTJ...
#
#
# 클라이드앤 경량 다운 롱패딩 CJDDU903F
#
#
# 지오다노 초경량 퀼팅 숏자켓 379907
#
#
# 지컷 큐트 폭스퍼 후드 구스다운 점퍼 7259...
#
#
# 시슬리 폭스 퍼 구스다운 패딩 SAPD80961
#
#
# 아디다스 락업 트랙팬츠 우먼스 LOCK UP TP...
#
#
# 온앤온 19겨울 폭스후드 구스 숏패딩 NP9WM...
#
#
# 뉴발란스 공용 2019년 UNI 액티브 구스 숏 ...
#
#
# 지오다노 여 메리노울 크루넥 스웨터 7GG 3...
#
#
# 지컷 롱벨티드 패딩 7259417004
#
#
# 일리코 코듀로이 밍크안감 배기 밴딩팬츠 골...
#
#
# 지오다노 여 초경량 퀼팅 숏자켓379907  37...
#
#
# ...
